# %% [markdown]
# <a href="https://colab.research.google.com/github/Lindart0312/machine-learning-practice/blob/main/second_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 나의 두번째 코랩
# ## 실습 내용
# -  실습1 :Google의 Colab으로 첫번째 파일 생성
# -  실습2 :Git레포지토리 생성
# -  실습3 :Colab 제공 기능으로 github에 업로드하기

# %% [markdown]
# ## hello world 출력하기
# - ptint 함수 사용

# %%
print() # 프린트 하는 함수'''

# %%
print("hello world")

# %% [markdown]
# ## 2. tensorflow 모듈 불러오기

# %%
# !pip install tensorflow # !없으면 파이썬으로 인식'''

# %%
import tensorflow as tf # import해야 tf사용가능'''

# %%
tf.__veriosn__
# Out:
# '2.19.0'

# %% [markdown]
# ## 클래스와 속성
# - 클래스는 속성과 메소드가 다 들어가있는 것
# - 하나의 주제에 대해 포괄적인 개념
# ### ex. 학생 클래스
# - 이름, 아이디, 주소 등이 포함됨
# ### 왜 생김
# - 협업할때, 해당 부분을 빠르게 찾기 위해서
# ### .__version__
# - 이거는 속성값, 어떤 값이 *들어가있는*

# %%
# !pwd # 내 파일이 어디있는지
# Out:
# /content
